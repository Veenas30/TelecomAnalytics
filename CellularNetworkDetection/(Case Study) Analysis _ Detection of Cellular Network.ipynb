# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="120" /></center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
# **1.** [**Introduction**](#Section1)<br>
# **2.** [**Problem Statement**](#Section2)<br>
# **3.** [**Installing & Importing Libraries**](#Section3)<br>
#   - **3.1** [**Installing Libraries**](#Section31)
#   - **3.2** [**Upgrading Libraries**](#Section32)
#   - **3.3** [**Importing Libraries**](#Section33)
#
# **4.** [**Data Acquisition & Description**](#Section4)<br>
#   - **4.1** [**Data Description**](#Section41)
#   - **4.2** [**Data Information**](#Section42)
#   - **4.3** [**Numerical Data Distribution**](#Section43)
#   - **4.4** [**Pre Profiling Report**](#Section44)
#
# **5.** [**Data Pre-processing**](#Section5)<br>
#   - **5.1** [**Identification & Handling of Missing Data**](#Section51)
#   - **5.2** [**Identification & Handling of Redundant Data**](#Section52)
#   - **5.3** [**Identification & Handling of Inconsistent Data Types**](#Section53)
#   - **5.4** [**Post Profiling Report**](#Section54)
#
# **6.** [**Exploratory Data Analysis**](#Section6)<br>
# **7.** [**Post Data Processing & Feature Selection**](#Section7)<br>
#   - **7.1** [**Encoding Categorical Features**](#Section71)
#   - **7.2** [**Feature Selection using Random Forest**](#Section72)
#   - **7.3** [**Data Preparation**](#Section73)
#
# **8.** [**Model Development & Evaluation**](#Section8)<br>
#   - **8.1** [**Logistic Regression**](#Section81)
#   - **8.2** [**Random Forest Classifier**](#Section82)
#   - **8.3** [**XGBoost Classifier**](#Section83)
#
# **9.** [**Conclusion**](#Section9)<br>
#
# ---

# %% [markdown]
# <a name = Section1></a>
#
# ---
# # **1. Introduction**
# ---
#
# - The advent of a 3G network with **more data, video calling and mobile internet** began in 1998.
#
# - 3G networks reach **2 mbps on stationary or non-moving devices** and **384kbps on devices in moving vehicles**.
#
# - 4G, or the current standard of cellular networks, was released in the late 2000s and is **<a href = "https://www.verizon.com/about/our-company/5g/difference-between-3g-4g-5g">500 times faster than 3G</a>**.
#
# - It has been able to support high-definition mobile TV, video conferencing and much more.
#
# - **Mobile device** in **motion** has **atmost 10s of Mbps** while at **stationary** it can be **100s of Mbps**. The **20MHz bandwidth sector** has **peak capacity of 400Mbps**.
#
# - However, since **users** are **sharing** available sector **capacity** among others, **observable speed** experiences by users are typically in **10s -100s of Mbps**.
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/DIfference-between-3G-4G-5G.jpeg"></center>
#
# **<center><h2>Earlier vs Current Scenario</h2></center>**
#
# **<h3>Earlier Scenario:</h3>**
#
# - **In 2010**, the **telecom sector** began **undergoing** a **major shift** as <a href = "https://www.businesstoday.in/magazine/trends/factors-that-are-contributing-to-death-of-3g-in-india/story/220551.html">**government sold spectrum for 3G**</a> for a **whopping Rs 67,719 crore**.
#
# - **3G** has **turned out** to be a **huge disappointment** **since launch** due to **quality services**, including both data speed and connectivity.
#
# - **“We are far too delayed," says** an **equipment provider**. The **lack of investment** in **3G networks** is **evident**.
#   - Consider this: **Out of a total 5.5 lakh cell towers** in India, **just 1.65 lakh are 3G-enabled**.
#
# - We have **pockets of 3G coverage**. So, **when people move out** of that pocket, they **fall into** a **2G network**.
#
# - **Telecom operators say** that their **inability** to **invest** in **3G networks** can also be **attributed** to **high taxes**.
#
# - **For every rupee** they earn, **30 paisa goes back to the government** in some **form of taxes and levies**, excluding income tax.
#
# - According to <a href = "https://www.businesstoday.in/story/jp-morgan-mulls-over-sale-of-india-mutual-fund-business/1/216942.html">**October 2014 report**</a>, JP Morgan said **subscribers graduating** from **2G to 3G** and **then to 4G might not take place in India**.
#
# - **Instead**, there could be a generation of **2G subscribers leapfrogging directly to 4G**, according to the report.
#
#
# **<h3>Current Scenario:</h3>**
#
# - <a href = "https://dazeinfo.com/2019/10/02/number-of-wireless-data-subscribers-in-india-by-network-type-graphfarm/">**Dazeinfo says**</a>, **India** is **currently** the **second-largest country** in the **world in terms** of the **no. of mobile subscribers** and **internet users**.
#
# - The **telecom industry** in **India** is **going through consolidation** after the **debut of Reliance Jio** with its **future-ready network**.
#
# - On the **other hand**, in order **to compete with Reliance Jio**, all the top **players have shaken hands**.
#
# - The **number of wireless data subscribers** in **India reached** an all-time high of **578.2 million** by the end of 2018.
#
# - **Interestingly**, a **whopping 75.4%** of them are **hooked to the 4G network**, followed by 2G and 3G.
#
# - As the **graph shows, between 2017 and 2018, about 197.8 million** new mobile **subscribers** were **connected** to the **4G network**.
#
# - **India had over 214.7 million 2G data subscribers** at the **end of 2014**, which **declined to 151.5 million at the end of 2016**.
#
# - **By the end of 2017, India recorded a whooping of 47% YoY** declined in its **number of 2G data subscribers**, **stood at only 79.8 million** and,
#
# - **By the end of 2017 number of 3G data subscribers** in India **declined from 105.4 million to the lowest 70.6 million** at the year ending 2018.
#
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/Number%20of%20Mobile%20Data%20Subscribers%20in%20India%2C%20by%20Network%20Type.png"></center>

# %% [markdown]
# <a name = Section2></a>
#
# ---
# # **2. Problem Statement**
# ---
#
# - **Most** of the **times**, **telecommunication** companies **struggle to give customers** the **network speed** that **they desire**.
#
# - **Unhappy/Unsatisfied customers** tend to either **raise complaints** or **leave** the **company**, which in **results** **loss** to the **company**.
#
# - If **company** can **identify** the **area providing range and strength** of the **network speed & quality**, they can **provide better services** for their **customers**.
#
# - Hence it brings **customer satisfaction**, **reduced churning rate**, **better personalized services etc.**
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/2g-3g-4g-learn.jpg"></center>
#
#
# **<h4>Scenario:</h4>**
#
# - **DeepBlue Network**, an **India** based company, provides **telecommunication services** to its **customers**.
#
# - They are **facing** an **issue** to **identify** the **quality & strength** of **cellular networks (3G & 4G)** in **different** geographical **areas**.
#
# - Due to which **some customers** are **facing issue** to **utilize** their **services** at **full extent**.
#
# - To **tackle** this **problem**, **company hired** a **team of data scientists**. Consider **you are one of them...**
#
# |Target Feature|Potential Values|
# | :-- | :-- |
# |network|4G|
# | |3G|

# %% [markdown]
# <a name = Section3></a>
#
# ---
# # **3. Installing & Importing Libraries**
# ---

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Installing Libraries**

# %%
# !pip install -q datascience                   # Package that is required by pandas profiling
# !pip install -q pandas-profiling              # Toolbox for Generating Statistics Report
# !pip install -q yellowbrick                   # Toolbox for Measuring Machine Performance
# !pip install -q category-encoders             # Transformers Toolbox to Encode Categorical Variables as Numeric
# Out:
#      |████████████████████████████████| 71kB 1.5MB/s
# ...
#      |████████████████████████████████| 81kB 1.7MB/s

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Upgrading Libraries**
#
# - After upgrading, you need to restart the runtime.
#
# - Make sure not to execute the cell 3.1 and cell below 3.2 again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling
# !pip install -q --upgrade yellowbrick
# Out:
#      |████████████████████████████████| 266kB 2.5MB/s
#      |████████████████████████████████| 604kB 7.4MB/s
#      |████████████████████████████████| 71kB 5.6MB/s
#      |████████████████████████████████| 71kB 5.5MB/s
#      |████████████████████████████████| 3.1MB 13.9MB/s
#      |████████████████████████████████| 61kB 5.8MB/s
#      |████████████████████████████████| 296kB 39.0MB/s
# ...
#      |████████████████████████████████| 266kB 1.9MB/s

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Importing Libraries**

# %%
# For Panel Data Analysis
import pandas as pd
from pandas_profiling import ProfileReport
import pandas.util.testing as tm
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('mode.chained_assignment', None)

# For Numerical Python
import numpy as np

# For Random seed values
from random import randint

# For Scientifc Python
from scipy import stats

# For datetime
from datetime import datetime as dt

# For Data Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# For imputing missing values
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer, KNNImputer

# For Preprocessing
from sklearn.preprocessing import StandardScaler

# For Feature Selection
from sklearn.feature_selection import SelectFromModel

# For Custom Transformers
from sklearn.base import BaseEstimator, TransformerMixin

# For Feature Importances
from yellowbrick.model_selection import FeatureImportances

# For metrics evaluation
from sklearn.metrics import precision_recall_curve, classification_report, plot_confusion_matrix

# For Data Modeling
from category_encoders import TargetEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# To handle class imbalance problem
from imblearn.over_sampling import SMOTE

# To Disable Warnings
import warnings
warnings.filterwarnings(action = "ignore")

# %% [markdown]
# <a name = Section4></a>
#
# ---
# # **4. Data Acquisition & Description**
# ---
#
# This data set is based on telecommunication network services provided by DeepBlue Network and is accessible <a href = "https://storage.googleapis.com/telecom-analytics/NetworkData.csv">**here**</a>.
#
# | Records | Features | Dataset Size |
# | :-- | :-- | :-- |
# | 513799 | 9 | 26.4 MB
#
# | # | Features | Description |
# | :-- | :--| :--|
# |01|**ServiceProvider**| The vendor that provides IT solutions and/or services to end users and organizations. Contains: [JIO, IDEA, AIRTEL, VODAFONE, CELLONE, DOLPHIN]|
# |02|**DownloadOrUpload**| Transfers taking place between the local device and the internet (in Kbps). Contains: [Download, Upload]|
# |03|**DataSpeed**|Speed of information transfer (in Kbps). Range: [0, 125819]|
# |04|**SignalStrength**|Transmitter power output as received by a reference antenna at a distance from the transmitting antenna (in dBm). Range: [-112.0, -50.0]|
# |05|**ServiceArea**|Area where the subscription is being provided. Contains: [Mumbai, Maharashtra, West Bengal, Andhra Pradesh, Madhya Pradesh, Tamil Nadu,  |
# |||UP East, Gujarat, Rajasthan, Punjab, Kerala, Bihar, Orissa, UP West, Karnataka, Assam, Chennai, Delhi, Himachal Pradesh, Kolkata, Haryana, North East, Jammu & Kashmir]|
# |06|**NetworkType**|Type of network. Contains: [3G, 4G]|
# |07|**Roaming**|Outside the geographical coverage area of the home network. Contains: [0 - Not roaming, 1 - Roaming]|
# |08|**Technology**|The technology being used by the network. Contains: [WIFI, LTE, CDMA, UTMS, EDGE]|
# |09|**Frequency**|Frequency of the network subscription in GHz.|

# %%
data = pd.read_csv('https://storage.googleapis.com/telecom-analytics/NetworkData.csv', encoding = 'latin1')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (513799, 9)
#   ServiceProvider DownloadOrUpload  DataSpeed  SignalStrength  ServiceArea  \
# 0             JIO         Download      11180           -95.0       Mumbai
# 1             JIO           Upload        573           -95.0       Mumbai
# 2             JIO         Download      46240           -65.0  Maharashtra
# 3             JIO           Upload       9481           -65.0  Maharashtra
# 4            IDEA         Download      17399           -74.0  Maharashtra
#
#   NetworkType  Roaming Technology  Frequency
# 0          4G        0       WIFI   2.755413
# 1          4G        0       WIFI   2.526763
# 2          4G        0        LTE   7.536897
# 3          4G        0        LTE   3.731417
# 4          4G        0        LTE   6.465990

# %% [markdown]
# <a name = Section41></a>
# ### **4.1 Data Description**
#
# - In this section we will get **information about the data** and see some observations.

# %%
print('Described Column Length:', len(data.describe().columns))
data.describe()
# Out:
# Described Column Length: 4
#            DataSpeed  SignalStrength        Roaming      Frequency
# count  513799.000000   461032.000000  513799.000000  513799.000000
# mean     9499.591821      -88.328689       0.499841       4.853796
# std     15475.013743       15.111830       0.500000       1.817471
# min         0.000000     -112.000000       0.000000       1.600004
# 25%       890.000000     -101.000000       0.000000       3.287474
# 50%      3356.000000      -91.000000       0.000000       4.856676
# 75%      9167.000000      -77.000000       1.000000       6.428236
# max    125819.000000      -50.000000       1.000000       7.999969

# %% [markdown]
# **Observation:**
#
# - **Average data speed observed** by **customer** is **9499 Kbps**.
#
# - **25%** of **customers observed data speed** of **890 Kbps** while **50% and 75%** of **customers observed data speed** of **3356 Kbps** and **9167 Kbps**.
#
# - **On average** there's **signal strenght** of **-88.32 dBm**.
#
# - **25%** of **customers** are **receiving signal strength** of **-101 dBm** while **50% and 75%** are **receiving signal strength** of **-91 dBm and -77 dBm**.
#
# - **50%** of **customers** are **not using roaming** service while only **75% of customers** are **using roaming**.
#
# - **On average customers** are **receiving 4.8 GHz** of **network frequency**.
#
# - **25%** of **customers** are **receiving network frequency** of **3.2 GHz** while **50% and 75%** of **customers** are **receiving network frequency** of **4.8 GHz and 6.4 GHz**.

# %% [markdown]
# <a name = Section42></a>
# ### **4.2 Data Information**
#
# - In this section we will see the **information about the types of features**.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513799 entries, 0 to 513798
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ServiceProvider   513799 non-null  object
#  1   DownloadOrUpload  513799 non-null  object
#  2   DataSpeed         513799 non-null  int64
#  3   SignalStrength    461032 non-null  float64
#  4   ServiceArea       509689 non-null  object
#  5   NetworkType       513799 non-null  object
#  6   Roaming           513799 non-null  int64
#  7   Technology        513799 non-null  object
#  8   Frequency         513799 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 35.3+ MB

# %% [markdown]
# **Observations:**
# - There are **9 features**, out of which **2 are float**, **2 are integer values**, **5 are object type values** and **1 is of boolean type**.
#
# - There are **missing values** present in the dataset.

# %% [markdown]
# <a name = Section43></a>
# ### **4.3 Numerical Data Distribution**
#
# - We shall plot all **numerical features to analyze the distribution** of their past.
#
# - But **before** that we must **extract** all the **numerical** **features** which has been **performed** **below**.

# %%
num_feature = []

for i in data.columns.values:
  if ((data[i].dtype == int) | (data[i].dtype == float)):
    num_feature.append(i)
    
print('Total Numerical Features:', len(num_feature))
print('Features:', num_feature)
# Out:
# Total Numerical Features: 4
# Features: ['DataSpeed', 'SignalStrength', 'Roaming', 'Frequency']

# %%
# Creating subplots
fig, axes = plt.subplots(nrows = 2, ncols = 2, sharex = False, figsize = (15, 6))

# Generating random colors based on number of columns
colors = []
for i in range(len(num_feature)):
  colors.append('#%06X' % randint(0, 0xFFFFFF))   
                
for ax, col, color in zip(axes.flat, num_feature, colors):
  sns.distplot(a = data[col], bins = 50, ax = ax, color = color)
  ax.set_title(col)
  plt.setp(axes, xlabel = '')
  ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
#
# - **Positively Skewed Features:**
#   - DataSpeed, SignalStrength, Roaming
#
# - **Negatively Skewed Features:**
#   - None
#
# - **Normally Distributed Features:**
#   - Frequency

# %% [markdown]
# <a id = Section44></a>
# ### **4.4 Pre Profiling Report**
#
# - For quick analysis pandas profiling is very handy.
# - Generates profile reports from a pandas DataFrame.
# - For each column statistics are presented in an interactive HTML report.

# %%
# profile = ProfileReport(df = data)
# profile.to_file(output_file = 'Pre Profiling Report.html')
# print('Accomplished!')
# Out:
# ...
# Accomplished!

# %%
# from google.colab import files                   # Use only if you are using Google Colab, otherwise remove it
# files.download('Pre Profiling Report.html')      # Use only if you are using Google Colab, otherwise remove it

# %% [markdown]
# **Observation:**
#
# - **Report shows** that there are **total 9 features** out of which **5 are categorical**, **3 are numerical** and **one boolean**.
#
# - There are **1.3% of missing cell** information.
#
# - There are **no duplicate** values present in the data.
#
# - **DataSpeed** has **high correlation** with **SignalStrength feature**.

# %% [markdown]
# <a name = Section5></a>
#
# ---
# # **5. Data Pre-Processing**
# ---

# %% [markdown]
# <a name = Section51></a>
# ### **5.1 Identification & Handling of Missing Data**

# %% [markdown]
# **Before Handling Missing Data**

# %%
missing_frame = pd.DataFrame(index = data.columns.values)
missing_frame['Null Frequency'] = data.isnull().sum().values
nullpercent = data.isnull().sum().values/data.shape[0]
missing_frame['Missing Null %age'] = np.round(nullpercent, decimals = 4) * 100
missing_frame['Zero Frequency'] = data[data == 0].count().values
zero_percent = data[data == 0].count().values / data.shape[0]
missing_frame['Missing %age'] = np.round(zero_percent, decimals = 4) * 100
missing_frame.transpose()
# Out:
#                    ServiceProvider  DownloadOrUpload  DataSpeed  \
# Null Frequency                 0.0               0.0        0.0
# Missing Null %age              0.0               0.0        0.0
# Zero Frequency                 0.0               0.0     2561.0
# Missing %age                   0.0               0.0        0.5
#
#                    SignalStrength  ServiceArea  NetworkType    Roaming  \
# Null Frequency           52767.00       4110.0          0.0       0.00
# Missing Null %age           10.27          0.8          0.0       0.00
# Zero Frequency               0.00          0.0          0.0  256981.00
# Missing %age                 0.00          0.0          0.0      50.02
#
#                    Technology  Frequency
# Null Frequency            0.0        0.0
# Missing Null %age         0.0        0.0
# Zero Frequency            0.0        0.0
# Missing %age              0.0        0.0

# %% [markdown]
# **Observation:**
#
# - **Feature:**
#   - Problem &rarr; Solution {Reason}
#
# - **DataSpeed:**
#   - Zero Data &rarr; None {Data Speed can be zero.}
#
# - **SignalStregth:**
#   - Null Data &rarr; Imputation of Median value using Iterative Imputer {Proportion is less & feature is numerical.}
#
# - **ServiceArea:**
#   - Null Data &rarr; Imputation of Mode value {Proportion is less & feature is categorical.}
#
# - **Roaming:**
#   - Zero Data &rarr; None {Feature is boolean.}

# %% [markdown]
# **<h4>Iterative Imputer (Default Estimator Used: Bayesian Ridge):</h4>**
#
# - This **approach** **generally** **referred** to as fully **conditional specification** (FCS) or **multivariate imputation by chained equations** (MICE).
#
# - It is a **very sophisticated approach** which **involves** **defining** a **model** to **predict each missing feature** as a function of all other features.
#
# - The **process** is **repeated multiple times** which **allows** the **refined estimated values** for other features to be used.
#
# - The **process works as where each feature is modeled as a function of the other features.** For example,
#   - A regression problem where missing values are predicted.
#
# - **Each feature** is **imputed** **sequentially**, **one after the other**, allowing **prior imputed values** to be **used** as **part of a model** in **predicting** subsequent **features**.
#
# |Step 1 (Identify)|Step 2 (Predict & Fill &rarr; Identify Again)|Step 3 (Predict & Fill)|
# |:-------------------------:|:-------------------------:|:-------------------------:|
# ![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/1%20Iterative%20Imputer.PNG)  |  ![img2](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/2%20Iterative%20Imputer.PNG) | ![img3](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/3%20Iterative%20Imputer.PNG)
#
# **<h4>Working of Above Example:</h4>**
#
# - **Step 1:** Imputer starts with the feature containing least number of missing values i.e. Age.
#
# - **Step 2:** Imputer predicts missing value with highly dense feature i.e. Height. Then it chooses next feature with least number of missing values.
#
# - **Step 3:** Imputer predicts with next highly dense feature. Now both Age and Height are highly dense because both have non-null values.

# %% [markdown]
# **Performing Operations:**

# %%
# For Numerical Features
iter_imp_num = IterativeImputer(random_state = 42, initial_strategy = 'median')
num_feat = iter_imp_num.fit_transform(data[['SignalStrength']])
num_frame = pd.DataFrame(data = num_feat, columns = ['SignalStrength'])
# Copying features to original dataframe
data['SignalStrength'] = num_frame['SignalStrength']

# For Categorical Features
data['ServiceArea'] = data['ServiceArea'].replace(np.nan, data['ServiceArea'].mode()[0])

# %% [markdown]
# **After Handling Missing Data**

# %%
missing_frame = pd.DataFrame(index = data.columns.values)
missing_frame['Null Frequency'] = data.isnull().sum().values
nullpercent = data.isnull().sum().values/data.shape[0]
missing_frame['Missing Null %age'] = np.round(nullpercent, decimals = 4) * 100
missing_frame['Zero Frequency'] = data[data == 0].count().values
zero_percent = data[data == 0].count().values / data.shape[0]
missing_frame['Missing %age'] = np.round(zero_percent, decimals = 4) * 100
missing_frame.transpose()
# Out:
#                    ServiceProvider  DownloadOrUpload  DataSpeed  \
# Null Frequency                 0.0               0.0        0.0
# Missing Null %age              0.0               0.0        0.0
# Zero Frequency                 0.0               0.0     2561.0
# Missing %age                   0.0               0.0        0.5
#
#                    SignalStrength  ServiceArea  NetworkType    Roaming  \
# Null Frequency                0.0          0.0          0.0       0.00
# Missing Null %age             0.0          0.0          0.0       0.00
# Zero Frequency                0.0          0.0          0.0  256981.00
# Missing %age                  0.0          0.0          0.0      50.02
#
#                    Technology  Frequency
# Null Frequency            0.0        0.0
# Missing Null %age         0.0        0.0
# Zero Frequency            0.0        0.0
# Missing %age              0.0        0.0

# %% [markdown]
# **Observation:**
#
# - We have **successfully** **handled** **missing** **data**.

# %% [markdown]
# <a name = Section52></a>
# ### **5.2 Identification & Handling of Redundant Data**
#
# - In this section **we will identify redundant rows and columns** in our data if present.
#
# - For handling duplicate features we have created a custom function to identify duplicacy in features with different name but similar values:

# %%
def duplicate_cols(dataframe):
  ls1 = []
  ls2 = []

  columns = dataframe.columns.values
  for i in range(0, len(columns)):
    for j in range(i+1, len(columns)):
      if (np.where(dataframe[columns[i]] == dataframe[columns[j]], True, False).all() == True):
        ls1.append(columns[i])
        ls2.append(columns[j])

  if ((len(ls1) == 0) & (len(ls2) == 0)):
    return None
  else:
    duplicate_frame = pd.DataFrame()
    duplicate_frame['Feature 1'] = ls1
    duplicate_frame['Feature 2'] = ls2
    return duplicate_frame

# %%
print('Contains Redundant Records?:', data.duplicated().any())
print('Duplicate Count:', data.duplicated().sum())
print('-----------------------------------------------------------------------')
print('Contains Redundant Features?:', duplicate_cols(data))
# Out:
# Contains Redundant Records?: False
# Duplicate Count: 0
# -----------------------------------------------------------------------
# Contains Redundant Features?: None

# %% [markdown]
# **Observations:**
# - There are **neither duplicate rows nor duplicate features** in the dataset.

# %% [markdown]
# <a name = Section53></a>
# ### **5.3 Identification & Handling of Inconsistent Data Types**
#
# - In this section we will **identify** and **handle** the **feature** that may **contains inconsistent data type**.

# %%
data.head(2)
# Out:
#   ServiceProvider DownloadOrUpload  DataSpeed  SignalStrength ServiceArea  \
# 0             JIO         Download      11180           -95.0      Mumbai
# 1             JIO           Upload        573           -95.0      Mumbai
#
#   NetworkType  Roaming Technology  Frequency
# 0          4G        0       WIFI   2.755413
# 1          4G        0       WIFI   2.526763

# %%
type_frame = pd.DataFrame(data = data.dtypes, columns = ['Type'])
type_frame.transpose()
# Out:
#      ServiceProvider DownloadOrUpload DataSpeed SignalStrength ServiceArea  \
# Type          object           object     int64        float64      object
#
#      NetworkType Roaming Technology Frequency
# Type      object   int64     object   float64

# %% [markdown]
# **Observation:**
#
# - All the **features** seems to **have correct data type**.

# %% [markdown]
# <a name = Section54></a>
# ### **5.4 Post Profiling Report**
#
# - In post profiling, we identify the changes over cleansed data.

# %%
# profile = ProfileReport(df = data)
# profile.to_file(output_file = 'Post Profiling Report.html')
# print('Accomplished!')
# Out:
# ...
# Accomplished!

# %%
#from google.colab import files                   # Use only if you are using Google Colab, otherwise remove it
#files.download('Post Profiling Report.html')     # Use only if you are using Google Colab, otherwise remove it

# %% [markdown]
# **Observation:**
#
# - **Apart** from **handling of missing information** there's **no major change**.

# %% [markdown]
# <a name = Section6></a>
#
# ---
# # **6. Exploratory Data Analysis**
# ---

# %% [markdown]
# **<h4>Question 1: What is the frequency & proportion of the different networks in the dataset?</h4>**

# %%
fig = plt.figure(figsize = [15, 8])
plt.subplot(1, 2, 1)
sns.countplot(x = 'NetworkType', data = data, palette = ['#1F77B4', '#FF7F0E'])
plt.xlabel(xlabel = 'Network Type', size = 14)
plt.ylabel(ylabel = 'Frequency', size = 14)
plt.grid(b = True)
plt.title(label = 'Frequency Distribution', size = 14)

plt.subplot(1, 2, 2)
space = np.ones(2)/10
data['NetworkType'].value_counts().plot(kind = 'pie', explode = space, fontsize = 14, autopct = '%3.1f%%', wedgeprops = dict(width=0.15), 
                                       shadow = True, startangle = 160, figsize = [15, 8], legend = True)
plt.legend(['4G', '3G'])
plt.ylabel(ylabel = 'NetworkType', size = 14)
plt.title(label = 'Proportion Distribution', size = 14)
plt.tight_layout(pad = 3.0)
plt.suptitle(t = 'Frequency & Proportion of Cellular Network Type', y = 1.02, size = 16)
plt.show()

# %% [markdown]
# **Observations:**
#
# - Around **95% of customers** are **using 4G** while only **4.5%** of **customers** are **using 3G**.
#
# - This **low proportion** of **3G** is **due to** the **fact** that **customers** are **slowly shifting** to **4G**.

# %% [markdown]
# **<h4>Question 2: What is the frequency distribution of different service providers in 3G and 4G network?**

# %%
service_provider_frame = pd.DataFrame(data.groupby(by = ['ServiceProvider', 'NetworkType']).size(), columns = ['Count'])
service_provider_frame.transpose()
# Out:
# ServiceProvider AIRTEL         CELLONE       DOLPHIN  IDEA            JIO  \
# NetworkType         3G      4G      3G    4G      3G    3G     4G      4G
# Count             1217  115807   14699  5524      12  4097  46334  280646
#
# ServiceProvider VODAFONE
# NetworkType           3G     4G
# Count               3232  42231

# %%
figure = plt.figure(figsize = [15, 8])
ax = sns.countplot(x = 'ServiceProvider', hue = 'NetworkType', data = data, palette = ['#566FDB', '#56DB7F'])

total = data.shape[0]
for p in ax.patches:
  percentage = '{:.2f}%'.format(100*p.get_height()/total)
  x = p.get_x() + p.get_width() / 6
  y = p.get_y() + p.get_height() + 2
  ax.annotate(percentage, (x, y))

plt.xlabel(xlabel = 'Service Provider', size = 14)
plt.ylabel(ylabel = 'Frequency', size = 14)
plt.title(label = 'Frequency Distribution of Service Providers (in 3G or 4G)', size = 16)
plt.legend(labels = ['4G', '3G'], loc = 'upper right')
plt.grid(b = True)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that **JIO has most users** and they are **only providing 4G services**.
#
# - **AIRTEL** is **running second in race** in terms of **providing 4G as well as 3G services**.
#
# - **IDEA & VODAFONE** are **still in race** atleast, **but** they **still need to develop strategies** to **grow their business**.
#
# - **CELLONE** company is **having most** of its **customers with 3G**. They **should** also **upgrade their network** to **retain their customers**.
#
# - If you see **DOLPHIN** is **only providing 3G services** with **least frequency of customers**. Looks like this company is gone for good.

# %% [markdown]
# **<h4>Question 3: Which is the frequency distribution of customer based on the Service Area?</h4>**

# %%
grouped_area = data.groupby(by = 'ServiceArea', as_index = False).agg('count')
grouped_area['count'] = grouped_area['ServiceProvider']
grouped_area.sort_values(by = 'count', ascending = False, inplace = True)
grouped_area.reset_index(drop = True, inplace = True)
first_half = grouped_area.iloc[:12, :]
second_half = grouped_area.iloc[12:, :]

# %%
plt.figure(figsize = [15, 8])
plt.subplot(1, 2, 1)
sns.barplot(x = 'count', y = 'ServiceArea', data = first_half)
plt.xlabel(xlabel = 'Frequency', size = 14)
plt.ylabel(ylabel = 'Service Area', size = 14)
plt.title(label = 'Service Area (First 12)', size = 14)

plt.subplot(1, 2, 2)
sns.barplot(x = 'count', y = 'ServiceArea', data = second_half)
plt.xlabel(xlabel = 'Frequency', size = 14)
plt.ylabel(ylabel = 'Service Area', size = 14)
plt.title(label = 'Service Area (Final 11)', size = 14)
plt.suptitle(t = 'Frequency Distribution of Customers in Different Service Area', y = 1, size = 16)
plt.tight_layout(pad = 3.0)
plt.show()

# %% [markdown]
# **Observations:**
# - The service areas **range from North to South and East to West of India**.
#
# - **Maximum records found in UP East** followed by **Maharashtra and then Delhi**.

# %% [markdown]
# **<h4>Question 4: What is the frequency distribution of  technologies that are being used by cellular networks?</h4>**

# %%
figure = plt.figure(figsize = [15, 7])

ax = sns.countplot(x = 'Technology', hue = 'NetworkType', data = data, palette = ['#F67088', '#38A7D0'])
total = data.shape[0]

for p in ax.patches:
  percentage = '{:.2f}%'.format(100 * p.get_height() / total)
  x = p.get_x() + p.get_width() / 5
  y = p.get_y() + p.get_height()
  ax.annotate(percentage, (x, y))

plt.xlabel('Technology', size = 14)
plt.xticks(rotation = 0)
plt.ylabel('Percentage', size = 14)
plt.legend(labels = ['4G', '3G'])
plt.grid(b = True)
plt.title('Technology being used by 3G and 4G networks', size = 16)
plt.show()

# %% [markdown]
# **Observations:**
# - **4G networks** use **LTE and WIFI** technologies.
#
# - **3G networks** use **CDMA, UMTS and EDGE** technologies.

# %% [markdown]
# **<h4>Question 5: What is the frequency distribution of the frequencies of the available networks?</h4>**

# %%
plt.figure(figsize = [15, 8])
sns.kdeplot(data = data[data['NetworkType'] == '4G']['Frequency'])
sns.kdeplot(data = data[data['NetworkType'] == '3G']['Frequency'])
plt.xlabel('Network Frequency (in GHz)', size = 14)
plt.ylabel('Frequency', size = 14)
plt.grid(b = True)
plt.legend(['4G', '3G'], loc = 'upper right')
plt.title('Frequency distribution of Cellular Frequencies (3G or 4G Network)', size = 16)
plt.show()

# %% [markdown]
# **Observations:**
# - The frequency values range from **1.6 GHz to 8 GHz**.
#
# - For **3G networks**, the frequencies range from **1.6 GHz to 2 GHz** whereas, **4G networks lie in the range of 2 GHz to 8 GHz**.

# %% [markdown]
# **<h4>Question 6: What is the frequency distribution of the signal strength of the available networks?</h4>**

# %%
plt.figure(figsize = [15, 8])
sns.kdeplot(data = data[data['NetworkType'] == '4G']['SignalStrength'])
sns.kdeplot(data = data[data['NetworkType'] == '3G']['SignalStrength'])
plt.xlabel('Signal Strength (in dBm)', size = 14)
plt.ylabel('Frequency', size = 14)
plt.grid(b = True)
plt.legend(['4G', '3G'], loc = 'upper right')
plt.title('Frequency distribution of Signal Strength (3G or 4G Network)', size = 16)
plt.show()

# %% [markdown]
# **Observations:**
# - The frequency values lie in the range of **-112 dBm to -50 dBm**.
# - **dBm** specifies **decibels relative to one milliwatt**.
# - The signal strength ranges are as follows:
#   - **Excellent**: **-70 dBm** on a **3G network**, **-90 dBm** on **4G/LTE network**.
#   - **Good**: **-71 to-85 dBm** on **3G network** and **-91 to -105 dBm** on **4G/LTE network**.
#   - **Fair**: **-86 to -100 dBm** on **3G network** and **-106 to -110 dBm** on **4G/LTE network**.
#   - **Poor**: **-101 to -109 dBm** on **3G network** and **-111 to -119 dBm** on **4G/LTE network**.
#   - **Dead Zone**: **-110 dBm** on **3G network** and **-120 dBm** on **4G/LTE network**.

# %% [markdown]
# **Note:** These are few question, from here if you would like to explore further, you are most welcome.

# %% [markdown]
# <a name = Section7></a>
#
# ---
# # **7. Post Data Processing & Feature Selection**
# ---
# - In this part we will **perform encoding over categorical features** and **feed it** to the **Random Forest** because machines can't understand human language.
#
# - **Random Forest** will then **identify important features** for our model **using threshold** over the information gain over reduction in impurity.
#
# - And **finally** we will **split** our **data** for the **model development**.

# %% [markdown]
# <a name = Section71></a>
# ### **7.1 Encoding Categorical Features**
#
# - Before encoding the features we must identify the cardinality of the features.
# - Then decide which type of encoding we should perform (Target, Dummy etc.).

# %%
cat_features = []
label_len = []

# Identify Categorical Features
for i in data.columns:
  if (data[i].dtype == object):
    cat_features.append(i)

# Identify Labels Length per Feature
for i in cat_features:
  label_len.append(len(data[i].unique()))

print('Total Categorical Features:', len(cat_features))

# Categorical Feature Frame Representation
cat_frame = pd.DataFrame(data = {'Length': label_len}, index = cat_features)
cat_frame.transpose()
# Out:
# Total Categorical Features: 5
#         ServiceProvider  DownloadOrUpload  ServiceArea  NetworkType  \
# Length                6                 2           23            2
#
#         Technology
# Length           5

# %% [markdown]
# **Observation:**
#
# - We can **observe** that **Service Area** has **high cardinality labels**. We will **perform K Fold Target Encoding** over this feature.
#
# - As **Network Type** is our **target** in this use case, we **won't perform** any **encoding operation over it**.
#
# - For **rest** of the **features** we will **perform dummy encoding**.
#
# - For **KFold Target Encoding** we have **created a class** as follows:

# %% [markdown]
# **<h4>K Fold Target Encoding:</h4>**
#
# - **Target encoding** is **one of the most powerful** **techniques** in feature engineering.
#
# - It has been **widely applied** and **developed** in **different forms**.
#
# - The **limitation** of **Target Encoding** is the **overfitting** of the **data**.
#
# - The **goal** of **K Fold Target Encoding** is to **reduce** the **overfitting** by **adding regularization** to the mean encoding.
#
# - Let's take an example as follows:
#
# |Example|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/te1.PNG)  | Here the count of A = 10, B = 10. The Mean(A): 6/10 = 0.6, Mean(B): 3/10 = 0.3|
#
# - In the above diagram, we can observer overfitting over label A. To handle this overfitting we will perform 5 fold target encoding.
#
# - Each fold's categories are encoded based on the mean of the rest of the fold's categories.
#
# - For first fold, mean values are estimated based on the rest of the folds i.e. Fold 2, Fold 3, Fold 4 & Fold 5.
#
# |Fold 1 View|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/kte2.PNG)  |The Mean(A): 5/9 = 0.556, Mean(B): 2/7 = 0.285|
#
# - For second fold, mean values are estimated based on the rest of the folds i.e. Fold 1, Fold 3, Fold 4 & Fold 5.
#
# |Fold 2 View|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/kte3.PNG)  |The Mean(A): 5/8 = 0.625, Mean(B): 2/8 = 0.250|
#
# - For third fold, mean values are estimated based on the rest of the folds i.e. Fold 1, Fold 2, Fold 4 & Fold 5.
#
# |Fold 3 View|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/kte4.PNG)  |The Mean(A): 5/7 = 0.714, Mean(B): 3/9 = 0.333|
#
# - For fourth fold, mean values are estimated based on the rest of the folds i.e. Fold 1, Fold 2, Fold 3 & Fold 5.
#
# |Fold 4 View|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/kte5.PNG)  |The Mean(A): 5/8 = 0.625, Mean(B): 2/8 = 0.250|
#
# - For fifth fold, mean values are estimated based on the rest of the folds i.e. Fold 1, Fold 2, Fold 3 & Fold 4.
#
# |Fold 5 View|Calculation |
# |:-------------------------:|:-------------------------:|
# |![img1](https://raw.githubusercontent.com/insaid2018/Domain_Case_Studies/master/Telecom/kte6.PNG)  |The Mean(A): 4/8 = 0.500, Mean(B): 3/8 = 0.375|

# %%
class KFoldTargetEncoder(BaseEstimator, TransformerMixin):
  def __init__(self ,colnames , targetName, n_fold = 5, verbosity = True, discardOriginal_col = False):
    self.colnames = colnames
    self.targetName = targetName
    self.n_fold = n_fold
    self.verbosity = verbosity
    self.discardOriginal_col = discardOriginal_col

  def fit(self, X, y = None):
    return self

  def transform(self,X):
    assert(type(self.targetName) == str)
    assert(type(self.colnames) == str)
    assert(self.colnames in X.columns)
    assert(self.targetName in X.columns)
    mean_of_target = X[self.targetName].mean()
    kf = KFold(n_splits = self.n_fold, shuffle = False, random_state = 42)
    col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
    X[col_mean_name] = np.nan
    for tr_ind, val_ind in kf.split(X):
      X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
      X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
      X[col_mean_name].fillna(mean_of_target, inplace = True)
    if self.verbosity:
      encoded_feature = X[col_mean_name].values
      print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name, self.targetName, np.corrcoef(X[self.targetName].values, encoded_feature)[0][1]))
    if self.discardOriginal_col:
      X = X.drop(self.colnames, axis=1)
    return X

# %% [markdown]
# **Performing Operations:**

# %%
# Dummy Encoding -> ServiceProvider, DownloadOrUpload, Technology
data = pd.get_dummies(data = data, columns = ['ServiceProvider', 'DownloadOrUpload', 'Technology'])

################################################################################

# Need to convert target with number for target encoding.
data['NetworkType'] = data['NetworkType'].apply(lambda x: 0 if x == '3G' else 1)

# Performing Target Encoding -> ServiceArea
kfold_te = KFoldTargetEncoder(colnames = 'ServiceArea', targetName = 'NetworkType', discardOriginal_col = True)
data = kfold_te.fit_transform(X = data)

# Reverse Transformation of Network Type to its original values
data['NetworkType'] = data['NetworkType'].apply(lambda x: '3G' if x == 0 else '4G')
# Out:
# Correlation between the new feature, ServiceArea_Kfold_Target_Enc and, NetworkType is 0.17725903039301055.

# %% [markdown]
# <a name = Section72></a>
# ### **7.2 Feature Selection using Random Forest**
#
# - Now in **real world**, it is very **rare** that **all** the **features** are **important** while developing the model.
#
# - So **instead** we **analyze** the **impact** of **input over the target**, either done by performing **statistical** **tests**(Pearson, ANOVA, Chi-Square) or by using **Random Forest**.
#
# - **Random forests** are one the most **popular machine learning algorithms** because they **provide**:
#  - **a good predictive performance**,
#  - **low overfitting and**
#  - **easy interpretability.**
#
# - This **interpretability** is **derived** from the **importance of each feature** on the tree decision **evaluated** on the **reduction** in **impurity**.
#
# - In other words, it is **easy to compute** how much **each feature is contributing** to the **decision**.
#
# - **Below** we have **implemented** a function namely, **SelectFromModel** **available** in **Sklearn** which **uses** the **base estimator** to **identify** **important features**.
#
# - The **importance** of feature is **determined** on the **basis** of **threshold** (a measure to calculate feature importance).

# %%
X = data.drop('NetworkType', axis = 1)
y = data['NetworkType']

# %%
# Have some patience, may take some time :)
selector = SelectFromModel(RandomForestClassifier(n_estimators = 100, random_state = 42, n_jobs = -1))
selector.fit(X, y)

# Extracting list of important features
selected_feat = X.columns[(selector.get_support())].tolist()

print('Total Features Selected are', len(selected_feat))

# Estimated by taking mean(default) of feature importance
print('Threshold set by Model:', np.round(selector.threshold_, decimals = 2))
print('Features:', selected_feat)
# Out:
# Total Features Selected are 5
# Threshold set by Model: 0.06
# Features: ['Frequency', 'ServiceProvider_CELLONE', 'Technology_EDGE', 'Technology_LTE', 'Technology_UMTS']

# %% [markdown]
# **Observation:**
#
# - The important features marked by Random Forest are:
#
# |Frequency|ServiceProvider_CELLONE|Technology_EDGE|Technology_LTE|Technology_UMTS|
# |:--|:--|:--|:--|:--|

# %% [markdown]
# **Potential Feature Estimation:** Below features are plotted against their relative importance (in %age),  of each feature.

# %%
# Have some patience, may take some time :)
figure = plt.figure(figsize = [15, 8])

# If you don't want relative importance, use relative = False in below method
viz = FeatureImportances(selector.estimator, relative = False)
viz.fit(X, y)

plt.xlabel('Relative Importance', size = 14)
plt.ylabel('Features', size = 14)
plt.title(label = 'Feature Importances', size = 16)
plt.show()

# %% [markdown]
# <a name = Section73></a>
# ### **7.3 Data Preparation**
#
# - Now we will **split** our **data** in **training** and **testing** part for further development.

# %%
X = data[selected_feat]
y = data['NetworkType']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42, stratify = y)

print('Training Data Shape:', X_train.shape, y_train.shape)
print('Testing Data Shape:', X_test.shape, y_test.shape)
# Out:
# Training Data Shape: (462419, 5) (462419,)
# Testing Data Shape: (51380, 5) (51380,)

# %% [markdown]
# **Observation:**
#
# - Now that we have split out our data, we are **good to go with model development**.

# %% [markdown]
# <a name = Section8></a>
#
# ---
# # **8. Model Development & Evaluation**
# ---
#
# - In this section we will **develop different models using only important feature** and **tune** our **model if required**.
#
# - Then we will **compare the results** obtained from them and **make our observation**.
#
# - For **evaluation purpose** we will **focus** on **recall value** for **both** the **classes**.
#
# - **Remember** that **we want generalize results** i.e. same results or error on testing data as that of training data.
#
# - We will **observer** **whether** the **SMOTE** is **required** or not **because** we want to **focus** on **recall** values of **both** the **classes**.

# %% [markdown]
# <a name = Section81></a>
# ## **8.1 Logistic Regression**

# %%
log  = LogisticRegression(random_state = 42, class_weight = 'balanced')
log.fit(X_train, y_train)

y_train_pred_count = log.predict(X_train)
y_test_pred_count = log.predict(X_test)

y_train_pred_proba = log.predict_proba(X_train)
y_test_pred_proba = log.predict_proba(X_test)

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, sharex = False, figsize=(15, 7))
plot_confusion_matrix(estimator = log, X = X_train, y_true = y_train, values_format = '.7g', cmap = 'YlGnBu', ax = ax1)
plot_confusion_matrix(estimator = log, X = X_test, y_true = y_test, values_format = '.7g', cmap = 'YlGnBu', ax = ax2)
ax1.set_title(label = 'Train Data', size = 14)
ax2.set_title(label = 'Test Data', size = 14)
ax1.grid(b = False)
ax2.grid(b = False)
plt.suptitle(t = 'Confusion Matrix', size = 16)
plt.show()

# %% [markdown]
# **Observation:**
#
# - **Train Data:**
#   - Model predicted **20931 instances correctly** for **negative class** while **441230 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 258 instances negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.
#
# - **Test Data:**
#   - Model predicted **2326 instances correctly** for **negative class** while **49025 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 29 instance negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.

# %%
logistic_report_train = classification_report(y_train, y_train_pred_count)
logistic_report_test = classification_report(y_test, y_test_pred_count)
print('                    Training Report          ')
print(logistic_report_train)
print('                    Testing Report           ')
print(logistic_report_test)
# Out:
#                     Training Report
#               precision    recall  f1-score   support
#
#           3G       0.99      1.00      0.99     20931
#           4G       1.00      1.00      1.00    441488
#
#     accuracy                           1.00    462419
#    macro avg       0.99      1.00      1.00    462419
# weighted avg       1.00      1.00      1.00    462419
#
#                     Testing Report
#               precision    recall  f1-score   support
#
#           3G       0.99      1.00      0.99      2326
#           4G       1.00      1.00      1.00     49054
#
#     accuracy                           1.00     51380
#    macro avg       0.99      1.00      1.00     51380
# weighted avg       1.00      1.00      1.00     51380

# %% [markdown]
# **Observation:**
#
# - We can observe that the **results are pretty good** on the default setting.
#
# - Let's see if we can achieve 100% accuracy on more complex models.

# %% [markdown]
# <a name = Section82></a>
# ## **8.2 Random Forest Classifier**

# %%
rfc = RandomForestClassifier(n_estimators = 100, n_jobs = -1, class_weight = 'balanced', random_state = 42)
rfc.fit(X_train, y_train)

y_train_pred_count = rfc.predict(X_train)
y_test_pred_count = rfc.predict(X_test)

y_train_pred_proba = rfc.predict_proba(X_train)
y_test_pred_proba = rfc.predict_proba(X_test)

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, sharex = False, figsize=(15, 7))
plot_confusion_matrix(estimator = rfc, X = X_train, y_true = y_train, values_format = '.7g', cmap = 'YlGnBu', ax = ax1)
plot_confusion_matrix(estimator = rfc, X = X_test, y_true = y_test, values_format = '.7g', cmap = 'YlGnBu', ax = ax2)
ax1.set_title(label = 'Train Data', size = 14)
ax2.set_title(label = 'Test Data', size = 14)
ax1.grid(b = False)
ax2.grid(b = False)
plt.suptitle(t = 'Confusion Matrix', size = 16)
plt.tight_layout(pad = 3.0)
plt.show()

# %% [markdown]
# **Observation:**
#
# - **Train Data:**
#   - Model predicted **20931 instances correctly** for **negative class** while **441488 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 0 instances negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.
#
# - **Test Data:**
#   - Model predicted **2326 instances correctly** for **negative class** while **49054 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 0 instance negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.

# %%
rfc_report_train = classification_report(y_train, y_train_pred_count)
rfc_report_test = classification_report(y_test, y_test_pred_count)
print('                    Training Report          ')
print(rfc_report_train)
print('                    Testing Report           ')
print(rfc_report_test)
# Out:
#                     Training Report
#               precision    recall  f1-score   support
#
#           3G       1.00      1.00      1.00     20931
#           4G       1.00      1.00      1.00    441488
#
#     accuracy                           1.00    462419
#    macro avg       1.00      1.00      1.00    462419
# weighted avg       1.00      1.00      1.00    462419
#
#                     Testing Report
#               precision    recall  f1-score   support
#
#           3G       1.00      1.00      1.00      2326
#           4G       1.00      1.00      1.00     49054
#
#     accuracy                           1.00     51380
#    macro avg       1.00      1.00      1.00     51380
# weighted avg       1.00      1.00      1.00     51380

# %% [markdown]
# **Observation:**
#
# - We can **observe 100% results** on both training and testing data.

# %% [markdown]
# <a name = Section83></a>
# ## **8.3 Extreme Gradient Boosting Classifier**

# %%
xgb = XGBClassifier(random_state = 42, n_jobs = -1)
xgb.fit(X_train, y_train)

y_train_pred_count = xgb.predict(X_train)
y_test_pred_count = xgb.predict(X_test)

y_train_pred_proba = xgb.predict_proba(X_train)
y_test_pred_proba = xgb.predict_proba(X_test)

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, sharex = False, figsize=(15, 7))
plot_confusion_matrix(estimator = xgb, X = X_train, y_true = y_train, values_format = '.7g', cmap = 'YlGnBu', ax = ax1)
plot_confusion_matrix(estimator = xgb, X = X_test, y_true = y_test, values_format = '.7g', cmap = 'YlGnBu', ax = ax2)
ax1.set_title(label = 'Train Data', size = 14)
ax2.set_title(label = 'Test Data', size = 14)
ax1.grid(b = False)
ax2.grid(b = False)
plt.suptitle(t = 'Confusion Matrix', size = 16)
plt.tight_layout(pad = 3.0)
plt.show()

# %% [markdown]
# **Observation:**
#
# - **Train Data:**
#   - Model predicted **20931 instances correctly** for **negative class** while **441488 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 0 instances negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.
#
# - **Test Data:**
#   - Model predicted **2326 instances correctly** for **negative class** while **49054 instances** were predicted **correctly** for **positive class**.
#   - Model **identified 0 instance negative but in actual** they **were positive**.
#   - Model **identified 0 instances positive but in actual** they **were negative**.

# %%
xgb_report_train = classification_report(y_train, y_train_pred_count)
xgb_report_test = classification_report(y_test, y_test_pred_count)
print('                    Training Report          ')
print(xgb_report_train)
print('                    Testing Report           ')
print(xgb_report_test)
# Out:
#                     Training Report
#               precision    recall  f1-score   support
#
#           3G       1.00      1.00      1.00     20931
#           4G       1.00      1.00      1.00    441488
#
#     accuracy                           1.00    462419
#    macro avg       1.00      1.00      1.00    462419
# weighted avg       1.00      1.00      1.00    462419
#
#                     Testing Report
#               precision    recall  f1-score   support
#
#           3G       1.00      1.00      1.00      2326
#           4G       1.00      1.00      1.00     49054
#
#     accuracy                           1.00     51380
#    macro avg       1.00      1.00      1.00     51380
# weighted avg       1.00      1.00      1.00     51380

# %% [markdown]
# **Observation:**
#
# - This **model** **also** **gave 100% results** on both training and testing data.

# %% [markdown]
# <a name = Section9></a>
#
# ---
# # **9. Conclusion**
# ---
#
# - We **studied in depth about the data**, its **characteristics** and its **distribution**.
#
# - We **explored various questions** related to whether a customer will churn or not.
#
# - We **investigated in depth about the features** which to **retain** and which to **discard**. List of retained features:
#
# |Frequency|ServiceProvider_CELLONE|Technology_EDGE|Technology_LTE|Technology_UMTS|
# |:--|:--|:--|:--|:--|
#
# - We **performed model development** with **variety** of **algorithms**:
#   - Logistic Regression, Random Forest, XGBoost
#
# - We **observed** that we **don't need to deal with class imbalance** because we are **getting good results** on the **imbalanced data** with **100% perfection**.
#
# - We can **either go with Random Forest or XGBoost**. It's just a matter of choice.
#
# - This **final model** now can **help us** in **identifying** which networks are 3G versus which networks are 4G.
